# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel(r'D:\1.Tekworks\Project\Healthcare Insurance Claim\Backend\1.Dataset\Encoder data\Encoded_data.xlsx')

# %%
data.head()
# Out:
#    Claim_Amount  Patient_Age  Patient_Gender  Patient_City  Patient_State  \
# 0     462337.48           28               0           937             19
# 1    1883481.30           40               2           980              2
# 2    1500658.89           90               0          1009              4
# 3     572237.61           49               2           998              9
# 4    2088293.84           24               0           976              4
#
#    Provider_City  Provider_State  Diagnosis_Code  Procedure_Code  \
# 0            981              18             968            1053
# 1           1017               0            1289            1273
# 2            967              12             987            1011
# 3            981              16            1002             973
# 4           1027              15             969             973
#
#    Number_of_Procedures  ...  Provider_Specialty_Physical Therapy  \
# ...

# %%
scale_columns = [
    'Claim_Amount',
    'Patient_Age',
    'Patient_City',
    'Provider_City',
    'Diagnosis_Code',
    'Procedure_Code',
    'Number_of_Procedures',
    'Length_of_Stay_Days',
    'Deductible_Amount',
    'CoPay_Amount',
    'Number_of_Previous_Claims_Patient',
    'Number_of_Previous_Claims_Provider',
    'Provider_Patient_Distance_Miles',
    'Claim_Year',
    'Claim_Month',
    'Claim_Delay_Days'
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

data[scale_columns] = scaler.fit_transform(data[scale_columns])

# %%
data.head()
# Out:
#    Claim_Amount  Patient_Age  Patient_Gender  Patient_City  Patient_State  \
# 0     -1.121339    -0.650370               0     -1.933469             19
# 1      0.913860    -0.194101               2     -0.733256              2
# 2      0.365625     1.707018               0      0.076190              4
# 3     -0.963953     0.148100               2     -0.230841              9
# 4      1.207168    -0.802460               0     -0.844904              4
#
#    Provider_City  Provider_State  Diagnosis_Code  Procedure_Code  \
# 0      -1.058893              18       -0.430195        0.399223
# 1       0.494558               0        2.530557        2.611934
# 2      -1.663013              12       -0.254948       -0.023204
# 3      -1.058893              16       -0.116595       -0.405399
# 4       0.926073              15       -0.420972       -0.405399
#
#    Number_of_Procedures  ...  Provider_Specialty_Physical Therapy  \
# ...

# %%
import pickle

pickle.dump(
    scaler,
    open("scaler.pkl", "wb")
)

# %%
data.to_excel(r'D:\1.Tekworks\Project\Healthcare Insurance Claim\Backend\1.Dataset\Scaling dataset\Scaling_data.xlsx', index=False)
